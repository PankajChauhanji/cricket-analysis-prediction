# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ipl.csv')
df1 = df[["venue", "total"]]
grouped_df = df1.groupby("venue")
grouped_df
mean_df = grouped_df.mean()
mean_df
mean_df = mean_df.reset_index()
mean_df
# Out:
#                                                 venue       total
# 0                                    Barabati Stadium  167.863318
# 1                                   Brabourne Stadium  180.468841
# 2                                        Buffalo Park  146.842105
# 3                               De Beers Diamond Oval  158.059783
# 4                          Dr DY Patil Sports Academy  147.568008
# 5   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  160.138365
# 6                 Dubai International Cricket Stadium  148.993088
# 7                                        Eden Gardens  156.768903
# 8                                    Feroz Shah Kotla  164.921619
# 9                                          Green Park  161.284553
# 10       Himachal Pradesh Cricket Association Stadium  175.901345
# 11                             Holkar Cricket Stadium  158.262561
# 12                 JSCA International Stadium Complex  148.945042
# ...

# %%
grouped_df = df1.groupby("venue")
grouped_df
mean_df = grouped_df.mean()
mean_df
mean_df = mean_df.reset_index()
mean_df
# Out:
#                                                 venue       total
# 0                                    Barabati Stadium  167.863318
# 1                                   Brabourne Stadium  180.468841
# 2                                        Buffalo Park  146.842105
# 3                               De Beers Diamond Oval  158.059783
# 4                          Dr DY Patil Sports Academy  147.568008
# 5   Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...  160.138365
# 6                 Dubai International Cricket Stadium  148.993088
# 7                                        Eden Gardens  156.768903
# 8                                    Feroz Shah Kotla  164.921619
# 9                                          Green Park  161.284553
# 10       Himachal Pradesh Cricket Association Stadium  175.901345
# 11                             Holkar Cricket Stadium  158.262561
# 12                 JSCA International Stadium Complex  148.945042
# ...

# %%
df1 = df[["venue", "total"]]
df1.head()
# Out:
#                    venue  total
# 0  M Chinnaswamy Stadium    222
# 1  M Chinnaswamy Stadium    222
# 2  M Chinnaswamy Stadium    222
# 3  M Chinnaswamy Stadium    222
# 4  M Chinnaswamy Stadium    222

# %%
Venue = "M Chinnaswamy Stadium"
df1 = df[(df["Venue_Name"] == Venue)]
df2 = df1[['Team1', 'Team2', 'Venue_Name', 'Toss_Winner', 'match_winner', 'Toss_Name']]
# Out:
#                            Team1                  Team2  \
# 0    Royal Challengers Bangalore  Kolkata Knight Riders
# 10   Royal Challengers Bangalore       Rajasthan Royals
# 14   Royal Challengers Bangalore    Chennai Super Kings
# 24   Royal Challengers Bangalore        Kings XI Punjab
# 30   Royal Challengers Bangalore         Mumbai Indians
# ..                           ...                    ...
# 607  Royal Challengers Bangalore          Gujarat Lions
# 619  Royal Challengers Bangalore        Kings XI Punjab
# 622  Royal Challengers Bangalore  Kolkata Knight Riders
# 634          Sunrisers Hyderabad  Kolkata Knight Riders
# 635               Mumbai Indians  Kolkata Knight Riders
#
#                 Venue_Name                  Toss_Winner  \
# 0    M Chinnaswamy Stadium  Royal Challengers Bangalore
# 10   M Chinnaswamy Stadium             Rajasthan Royals
# 14   M Chinnaswamy Stadium          Chennai Super Kings
# 24   M Chinnaswamy Stadium              Kings XI Punjab
# ...

# %%
# bat winner:
Venue = "M Chinnaswamy Stadium"
df1 = df[(df["Venue_Name"] == Venue)]
df2 = df1[['Team1', 'Team2', 'Venue_Name', 'Toss_Winner', 'match_winner', 'Toss_Name']]

df3 = df2[(df2["Toss_Winner"] == df2["match_winner"])&(df2["Toss_Name"] == "field")]
df4 = df2[(df2["Toss_Winner"] != df2["match_winner"])&(df2["Toss_Name"] == "bat")]
print(len(df3.index) + len(df4.index))

df5 = df2[(df2["Toss_Winner"] == df2["match_winner"])&(df2["Toss_Name"] == "bat")]
df6 = df2[(df2["Toss_Winner"] != df2["match_winner"])&(df2["Toss_Name"] == "field")]
print(len(df4.index) + len(df6.index))
# Out:
# 32
# 28

# %%
team_name = "Royal Challengers Bangalore"
df1 = df[(df["id"] < 100) & (df["Team1"] == team_name)]
df1.head(2)
# Out:
#     id                        Team1                  Team2 match_date  \
# 0    0  Royal Challengers Bangalore  Kolkata Knight Riders  4/18/2008
# 10  10  Royal Challengers Bangalore       Rajasthan Royals  4/26/2008
#
#     Season_Year             Venue_Name  City_Name Country_Name  \
# 0          2008  M Chinnaswamy Stadium  Bangalore        India
# 10         2008  M Chinnaswamy Stadium  Bangalore        India
#
#                     Toss_Winner           match_winner Toss_Name Win_Type  \
# 0   Royal Challengers Bangalore  Kolkata Knight Riders     field     runs
# 10             Rajasthan Royals       Rajasthan Royals     field  wickets
#
#    Outcome_Type    ManOfMach  Win_Margin
# 0        Result  BB McCullum       140.0
# 10       Result    SR Watson         7.0

# %%
# df.columns
df2 = df1['Team1', 'Team2', 'match_date', 'Season_Year', 'Venue_Name',
       'City_Name', 'Country_Name', 'Toss_Winner', 'match_winner', 'Toss_Name',
       'Win_Type', 'Outcome_Type', 'ManOfMach', 'Win_Margin']
# Out:
# Index(['id', 'Team1', 'Team2', 'match_date', 'Season_Year', 'Venue_Name',
#        'City_Name', 'Country_Name', 'Toss_Winner', 'match_winner', 'Toss_Name',
#        'Win_Type', 'Outcome_Type', 'ManOfMach', 'Win_Margin'],
#       dtype='object')

# %%
df3 = df1[['Team1', 'Team2', 'Venue_Name', 'Toss_Winner', 'match_winner', 'Toss_Name']]
df3.head(2)
df3.group_by("Venue")
# Out:
#                           Team1                  Team2             Venue_Name  \
# 0   Royal Challengers Bangalore  Kolkata Knight Riders  M Chinnaswamy Stadium
# 10  Royal Challengers Bangalore       Rajasthan Royals  M Chinnaswamy Stadium
#
#                     Toss_Winner           match_winner Toss_Name
# 0   Royal Challengers Bangalore  Kolkata Knight Riders     field
# 10             Rajasthan Royals       Rajasthan Royals     field

# %%
Venue = "M Chinnaswamy Stadium"
df4 = df[(df["Venue_Name"] == Venue)]
df4
# Out:
#     id                        Team1                  Team2  match_date  \
# 0    0  Royal Challengers Bangalore  Kolkata Knight Riders   4/18/2008
# 10  10  Royal Challengers Bangalore       Rajasthan Royals   4/26/2008
# 14  14  Royal Challengers Bangalore    Chennai Super Kings   4/28/2008
# 24  24  Royal Challengers Bangalore        Kings XI Punjab  05-05-2008
# 30  30  Royal Challengers Bangalore         Mumbai Indians   5/28/2008
# 44  44  Royal Challengers Bangalore       Delhi Daredevils   5/19/2008
# 51  51  Royal Challengers Bangalore        Deccan Chargers  05-03-2008
#
#     Season_Year             Venue_Name  City_Name Country_Name  \
# 0          2008  M Chinnaswamy Stadium  Bangalore        India
# 10         2008  M Chinnaswamy Stadium  Bangalore        India
# 14         2008  M Chinnaswamy Stadium  Bangalore        India
# 24         2008  M Chinnaswamy Stadium  Bangalore        India
# 30         2008  M Chinnaswamy Stadium  Bangalore        India
# ...

# %%
df2 = df1[['Team1', 'Team2', 'Venue_Name', 'Toss_Winner', 'match_winner', 'Toss_Name']]
# Out:
# <ipython-input-109-f4cec40f5baf>:1: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   df2 = df1[['Team1', 'Team2', 'Venue_Name', 'Toss_Winner', 'match_winner', 'Toss_Name']]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-109-f4cec40f5baf> in <module>
# ----> 1 df2 = df1[['Team1', 'Team2', 'Venue_Name', 'Toss_Winner', 'match_winner', 'Toss_Name']]
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df2.dropna(axit = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-48c4fa4734df> in <module>
# ----> 1 df2.dropna(axit = 1)
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
df1 = df["Venue_Name"].unique()
df1.dropna(axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-f7474f540b99> in <module>
#       1 df1 = df["Venue_Name"].unique()
# ----> 2 df1.dropna(axis = 1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dropna'

# %%
df2 = df1.tolist()
df2
# Out:
# ['M Chinnaswamy Stadium',
#  'Barabati Stadium',
#  'Rajiv Gandhi International Stadium Uppal',
#  'Punjab Cricket Association Stadium, Mohali',
#  'Saurashtra Cricket Association Stadium',
#  'Punjab Cricket Association IS Bindra Stadium, Mohali',
#  'Wankhede Stadium',
#  'Sawai Mansingh Stadium',
#  'Punjab Cricket Association IS Bindra Stadium Mohali',
#  'Vidarbha Cricket Association Stadium, Jamtha',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'Shaheed Veer Narayan Singh International Stadium',
#  'Subrata Roy Sahara Stadium',
#  "St George's Park",
#  'SuperSport Park',
#  nan,
#  'Brabourne Stadium',
#  'Sharjah Cricket Stadium',
#  'Himachal Pradesh Cricket Association Stadium',
#  'Nehru Stadium',
#  'Green Park',
#  'OUTsurance Oval',
#  'De Beers Diamond Oval',
#  'New Wanderers Stadium',
#  'Buffalo Park',
#  'Holkar Cricket Stadium',
#  'Kingsmead',
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#  'Newlands',
#  'Dr DY Patil Sports Academy',
# ...
