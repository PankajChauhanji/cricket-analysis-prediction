# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ipl_stats.csv')

# %%
df.head(2)
# Out:
#                Team     Player Tournament  Matches Batting Innings Not Out  \
# 0  Delhi Daredevils  CH Morris   IPL 2016       12               7       4
# 1  Delhi Daredevils  CH Morris   IPL 2017        9               9       4
#
#   Runds Scored Highest Score Batting Average Balls Faced  ... Runs Conceded  \
# 0          195           82*           65.00         109  ...           308
# 1          154           52*           30.80          94  ...           240
#
#   Wickets Taken Best Bowling Figures Bowling Average Bowling Economy Rate  \
# 0            13                 2/30           23.69                 7.00
# 1            12                 4/26           20.00                 7.74
#
#   Bowling Strike Rate 4+ Innings Wickets 5+ Innings Wickets Catches Taken  \
# 0                20.3                  0                  0             8
# 1                15.5                  1                  0             5
#
#   Stumpings Made
# 0              0
# 1              0
#
# ...

# %%
player_name = "CH Morris"
df1 = df[df["Player"] == player_name]
df2 = df1.groupby("Tournament")
df3 = df2.first().transpose()
df3
# Out:
# Tournament                    IPL 2016          IPL 2017          IPL 2018  \
# Team                  Delhi Daredevils  Delhi Daredevils  Delhi Daredevils
# Player                       CH Morris         CH Morris         CH Morris
# Matches                             12                 9                 4
# Batting Innings                      7                 9                 4
# Not Out                              4                 4                 3
# Runds Scored                       195               154                46
# Highest Score                      82*               52*               27*
# Batting Average                  65.00             30.80             46.00
# Balls Faced                        109                94                26
# Batting Strike Rate             178.89            163.82            176.92
# 100                                  0                 0                 0
# ...

# %%
df1 = df["Player"].unique()
df2 = df1.tolist()
df3 = []
for ele in df2:
    if type(ele) == str:
        df3.append(ele)
df3.sort()
df3
# Out:
# ['A Ashish Reddy',
#  'A Choudhary',
#  'A Dananjaya',
#  'A Mishra',
#  'A Nehra',
#  'A Zampa',
#  'AB Dinda',
#  'AB de Villiers',
#  'AD Hales',
#  'AD Mathews',
#  'AD Nath',
#  'AD Russell',
#  'AF Milne',
#  'AJ Finch',
#  'AJ Turner',
#  'AJ Tye',
#  'AM Rahane',
#  'AP Tare',
#  'AR Bawne',
#  'AR Patel',
#  'AS Joseph',
#  'AS Rajpoot',
#  'AS Roy',
#  'AT Rayudu',
#  'Abhishek Sharma',
#  'Ankit Sharma',
#  'Ankit Soni',
#  'Anureet Singh',
#  'Arshdeep Singh',
#  'Avesh Khan',
#  'B Kumar',
#  'B Laughlin',
#  'B Stanlake',
#  'BA Stokes',
#  'BB McCullum',
#  'BB Sran',
#  'BCJ Cutting',
#  'Basil Thampi',
#  'Bipul Sharma',
#  'C Munro',
#  'C de Grandhomme',
#  'CA Ingram',
#  'CA Lynn',
#  'CH Gayle',
#  'CH Morris',
#  'CJ Anderson',
#  'CJ Dala',
#  'CJ Jordan',
#  'CR Brathwaite',
#  'CR Woakes',
#  'CV Varun',
#  'D Wiese',
#  'DA Miller',
#  'DA Warner',
#  'DJ Bravo',
#  'DJ Hooda',
#  'DJ Willey',
#  'DJM Short',
#  'DL Chahar',
#  'DM Bravo',
#  'DR Shorey',
# ...
